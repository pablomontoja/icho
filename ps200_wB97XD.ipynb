# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
}
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %%
import glob
import py3Dmol

from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem import Draw
from rdkit.Chem import rdMolAlign
from rdkit.Chem.Draw import IPythonConsole
from rdkit import rdBase
print(rdBase.rdkitVersion)
import os,time
print( time.asctime())
# Out:
# 2016.09.4
# Tue Jun  5 11:44:23 2018

# %% [markdown]
# # ps200 + R-PEA

# %% [markdown]
# <table>
#     <tr>
#         <td><b>Nazwa pliku</b></td>
#         <td><b>G</b></td>
#         <td><b>Populacja</b></td>
#         <td><b>deltaG (kJ/mol)</b></td>
#     </tr>
#     <tr>
#         <td>ps200_RPEA_v3_105_wB97XD_631gd_INVERSION_FREQ.log</td>
#         <td>-4976.35390594</td>
#         <td>53.34%</td>
#         <td>0.0</td>
#     </tr>
#     <tr>
#         <td>ps200_RPEA_v3_105_wB97XD_631gd_INVERSION_V2_FREQ.log</td>
#         <td>-4976.35365328</td>
#         <td>40.82%</td>
#         <td>0.66</td>
#     </tr>
#     <tr>
#         <td>ps200_RPEA_v3_306_wB97XD_631gd_FREQ.log</td>
#         <td>-4976.35158314</td>
#         <td>4.56%</td>
#         <td>6.10</td>
#     </tr>
# </table>

# %% [markdown]
# ### ps200_RPEA_v3_105_wB97XD_631gd_INVERSION_FREQ.log (53.34%) NAJTRWALSZY

# %%
cm1 = open('structures/ps200_RPEA_v3_105_wB97XD_631gd_INVERSION_FREQ.xyz','r').read()
vcm1 = py3Dmol.view(width=800,height=800)
vcm1.removeAllModels()
vcm1.addModel(cm1,'xyz')
vcm1.setStyle({'stick':{'radius':0.10,'color':'spectrum'}})
vcm1.setBackgroundColor('0x000000')
vcm1.zoomTo()
vcm1.show()
# Out:
# <div id="3dmolviewer_15281918639341748"  style="position: relative; width: 800px; height: 800px">
# <script>
# if(typeof $3Dmolpromise === 'undefined') $3Dmolpromise = $.when($.getScript('http://3dmol.csb.pitt.edu/build/3Dmol.js'))
# var viewer_15281918639341748 = null;
# $3Dmolpromise.done(function() {
# viewer_15281918639341748 = $3Dmol.createViewer($("#3dmolviewer_15281918639341748"),{backgroundColor:"white"});
# 	viewer_15281918639341748.removeAllModels();
# ...

# %% [markdown]
# ### ps200_RPEA_v3_105_wB97XD_631gd_INVERSION_V2_FREQ.log (40.82%)

# %%
cm1 = open('structures/ps200_RPEA_v3_105_wB97XD_631gd_INVERSION_V2_FREQ.xyz','r').read()
vcm1 = py3Dmol.view(width=800,height=800)
vcm1.removeAllModels()
vcm1.addModel(cm1,'xyz')
vcm1.setStyle({'stick':{'radius':0.10,'color':'spectrum'}})
vcm1.setBackgroundColor('0x000000')
vcm1.zoomTo()
vcm1.show()
# Out:
# <div id="3dmolviewer_1528191863948364"  style="position: relative; width: 800px; height: 800px">
# <script>
# if(typeof $3Dmolpromise === 'undefined') $3Dmolpromise = $.when($.getScript('http://3dmol.csb.pitt.edu/build/3Dmol.js'))
# var viewer_1528191863948364 = null;
# $3Dmolpromise.done(function() {
# viewer_1528191863948364 = $3Dmol.createViewer($("#3dmolviewer_1528191863948364"),{backgroundColor:"white"});
# 	viewer_1528191863948364.removeAllModels();
# ...

# %% [markdown]
# # ps200 + S-PEA

# %% [markdown]
# <table>
#     <tr>
#         <td><b>Nazwa pliku</b></td>
#         <td><b>G</b></td>
#         <td><b>Populacja</b></td>
#         <td><b>deltaG (kJ/mol)</b></td>
#     </tr>
#     <tr>
#         <td>ps200_SPEA_v3_105_wB97XD_631gd_FREQ.log</td>
#         <td>-4976.35218364</td>
#         <td>98.7% </td>
#         <td>0.0</td>
#     </tr>
# </table>

# %% [markdown]
# ### ps199_SPEA_v1_11_wB97XD_631gd.log (98.7%) NAJTRWALSZY

# %%
cm1 = open('structures/ps200_SPEA_v3_105_wB97XD_631gd_FREQ.xyz','r').read()
vcm1 = py3Dmol.view(width=800,height=800)
vcm1.removeAllModels()
vcm1.addModel(cm1,'xyz')
vcm1.setStyle({'stick':{'radius':0.10,'color':'spectrum'}})
vcm1.setBackgroundColor('0x000000')
vcm1.zoomTo()
vcm1.show()
# Out:
# <div id="3dmolviewer_15281918639648793"  style="position: relative; width: 800px; height: 800px">
# <script>
# if(typeof $3Dmolpromise === 'undefined') $3Dmolpromise = $.when($.getScript('http://3dmol.csb.pitt.edu/build/3Dmol.js'))
# var viewer_15281918639648793 = null;
# $3Dmolpromise.done(function() {
# viewer_15281918639648793 = $3Dmol.createViewer($("#3dmolviewer_15281918639648793"),{backgroundColor:"white"});
# 	viewer_15281918639648793.removeAllModels();
# ...
