# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
}
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %%
import glob
import py3Dmol

from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem import Draw
from rdkit.Chem import rdMolAlign
from rdkit.Chem.Draw import IPythonConsole
from rdkit import rdBase
print(rdBase.rdkitVersion)
import os,time
print( time.asctime())
# Out:
# 2016.09.4
# Wed May 23 11:07:54 2018

# %% [markdown]
# # sacharoza5Bn + R-PEA

# %% [markdown]
# <table>
#     <tr>
#         <td><b>Nazwa pliku</b></td>
#         <td><b>G</b></td>
#         <td><b>Populacja</b></td>
#         <td><b>deltaG (kJ/mol)</b></td>
#     </tr>
#     <tr>
#         <td>sacharoza5Bn_RPEA_step_938_wB97XD_631gd_FREQ.log</td>
#         <td>-3014.468103</td>
#         <td>49.96%</td>
#         <td>0.0</td>
#     </tr>
#     <tr>
#         <td>sacharoza5Bn_RPEA_step_328_wB97XD_631gd_try2_FREQ.log</td>
#         <td>-3014.467955</td>
#         <td>42.72%</td>
#         <td>0.39</td>
#     </tr>
#     <tr>
#         <td>sacharoza5Bn_RPEA_step_775_wB97XD_631gd_FREQ.log</td>
#         <td>-3014.466053</td>
#         <td>5.70%</td>
#         <td>5.38</td>
#     </tr>
#     <tr>
#         <td>sacharoza5Bn_RPEA_step_796_wB97XD_631gd_FREQ.log</td>
#         <td>-3014.464322</td>
#         <td>0.91%</td>
#         <td>9.93</td>
#     </tr>
# </table>

# %% [markdown]
# ### sacharoza5Bn_RPEA_step_938_wB97XD_631gd_FREQ.log (49.96%) NAJTRWALSZY

# %%
cm1 = open('structures/sacharoza5Bn_RPEA_step_938_wB97XD_631gd_FREQ.xyz','r').read()
vcm1 = py3Dmol.view(width=800,height=800)
vcm1.removeAllModels()
vcm1.addModel(cm1,'xyz')
vcm1.setStyle({'stick':{'radius':0.10,'color':'spectrum'}})
vcm1.setBackgroundColor('0x000000')
vcm1.zoomTo()
vcm1.show()
# Out:
# <div id="3dmolviewer_15270664748371758"  style="position: relative; width: 800px; height: 800px">
# <script>
# if(typeof $3Dmolpromise === 'undefined') $3Dmolpromise = $.when($.getScript('http://3dmol.csb.pitt.edu/build/3Dmol.js'))
# var viewer_15270664748371758 = null;
# $3Dmolpromise.done(function() {
# viewer_15270664748371758 = $3Dmol.createViewer($("#3dmolviewer_15270664748371758"),{backgroundColor:"white"});
# 	viewer_15270664748371758.removeAllModels();
# ...

# %% [markdown]
# ### sacharoza5Bn_RPEA_step_328_wB97XD_631gd_try2_FREQ.log (42.72%)

# %%
cm1 = open('structures/sacharoza5Bn_RPEA_step_328_wB97XD_631gd_try2_FREQ.xyz','r').read()
vcm1 = py3Dmol.view(width=800,height=800)
vcm1.removeAllModels()
vcm1.addModel(cm1,'xyz')
vcm1.setStyle({'stick':{'radius':0.10,'color':'spectrum'}})
vcm1.setBackgroundColor('0x000000')
vcm1.zoomTo()
vcm1.show()
# Out:
# <div id="3dmolviewer_15270664748484306"  style="position: relative; width: 800px; height: 800px">
# <script>
# if(typeof $3Dmolpromise === 'undefined') $3Dmolpromise = $.when($.getScript('http://3dmol.csb.pitt.edu/build/3Dmol.js'))
# var viewer_15270664748484306 = null;
# $3Dmolpromise.done(function() {
# viewer_15270664748484306 = $3Dmol.createViewer($("#3dmolviewer_15270664748484306"),{backgroundColor:"white"});
# 	viewer_15270664748484306.removeAllModels();
# ...

# %% [markdown]
# ### sacharoza5Bn_RPEA_step_775_wB97XD_631gd_FREQ.log (5.7%)

# %%
cm1 = open('structures/sacharoza5Bn_RPEA_step_775_wB97XD_631gd_FREQ.xyz','r').read()
vcm1 = py3Dmol.view(width=800,height=800)
vcm1.removeAllModels()
vcm1.addModel(cm1,'xyz')
vcm1.setStyle({'stick':{'radius':0.10,'color':'spectrum'}})
vcm1.setBackgroundColor('0x000000')
vcm1.zoomTo()
vcm1.show()
# Out:
# <div id="3dmolviewer_15270664748591979"  style="position: relative; width: 800px; height: 800px">
# <script>
# if(typeof $3Dmolpromise === 'undefined') $3Dmolpromise = $.when($.getScript('http://3dmol.csb.pitt.edu/build/3Dmol.js'))
# var viewer_15270664748591979 = null;
# $3Dmolpromise.done(function() {
# viewer_15270664748591979 = $3Dmol.createViewer($("#3dmolviewer_15270664748591979"),{backgroundColor:"white"});
# 	viewer_15270664748591979.removeAllModels();
# ...

# %% [markdown]
# # sacharoza5Bn + S-PEA

# %% [markdown]
# <table>
#     <tr>
#         <td><b>Nazwa pliku</b></td>
#         <td><b>G</b></td>
#         <td><b>Populacja</b></td>
#         <td><b>deltaG (kJ/mol)</b></td>
#     </tr>
#     <tr>
#         <td>sacharoza5Bn_SPEA_step_938_wB97XD_631gd_INVERSION_try3_step_710_FREQ.log</td>
#         <td>-3014.471795</td>
#         <td>35.83%</td>
#         <td>0.0</td>
#     </tr>
#     <tr>
#         <td>sacharoza5Bn_SPEA_step_938_wB97XD_631gd_INVERSION_try3_step_18_wB97XD_631gd_FREQ.log</td>
#         <td>-3014.471795</td>
#         <td>30.12%</td>
#         <td>0.43</td>
#     </tr>
#     <tr>
#         <td>sacharoza5Bn_SPEA_step_938_wB97XD_631gd_INVERSION_try3_step_869_wB97XD_631gd_FREQ.log</td>
#         <td>-3014.471795</td>
#         <td>19.47%</td>
#         <td>1.51</td>
#     </tr>
#     <tr>
#         <td>sacharoza5Bn_SPEA_step_938_wB97XD_631gd_INVERSION_try3_step_1159_wB97XD_631gd_FREQ.log</td>
#         <td>-3014.471795</td>
#         <td>6.07%</td>
#         <td>4.40</td>
#     </tr>
# </table>

# %% [markdown]
# ### sacharoza5Bn_SPEA_step_938_wB97XD_631gd_INVERSION_try3_step_710_FREQ.log (35.83%) NAJTRWALSZY

# %%
cm1 = open('structures/sacharoza5Bn_SPEA_step_938_wB97XD_631gd_INVERSION_try3_step_710_FREQ.xyz','r').read()
vcm1 = py3Dmol.view(width=800,height=800)
vcm1.removeAllModels()
vcm1.addModel(cm1,'xyz')
vcm1.setStyle({'stick':{'radius':0.10,'color':'spectrum'}})
vcm1.setBackgroundColor('0x000000')
vcm1.zoomTo()
vcm1.show()
# Out:
# <div id="3dmolviewer_15270664748719678"  style="position: relative; width: 800px; height: 800px">
# <script>
# if(typeof $3Dmolpromise === 'undefined') $3Dmolpromise = $.when($.getScript('http://3dmol.csb.pitt.edu/build/3Dmol.js'))
# var viewer_15270664748719678 = null;
# $3Dmolpromise.done(function() {
# viewer_15270664748719678 = $3Dmol.createViewer($("#3dmolviewer_15270664748719678"),{backgroundColor:"white"});
# 	viewer_15270664748719678.removeAllModels();
# ...

# %% [markdown]
# ### sacharoza5Bn_SPEA_step_938_wB97XD_631gd_INVERSION_try3_step_18_wB97XD_631gd_FREQ.log (30.12%)

# %%
cm1 = open('structures/sacharoza5Bn_SPEA_step_938_wB97XD_631gd_INVERSION_try3_step_18_wB97XD_631gd_FREQ.xyz','r').read()
vcm1 = py3Dmol.view(width=800,height=800)
vcm1.removeAllModels()
vcm1.addModel(cm1,'xyz')
vcm1.setStyle({'stick':{'radius':0.10,'color':'spectrum'}})
vcm1.setBackgroundColor('0x000000')
vcm1.zoomTo()
vcm1.show()
# Out:
# <div id="3dmolviewer_15270664748821545"  style="position: relative; width: 800px; height: 800px">
# <script>
# if(typeof $3Dmolpromise === 'undefined') $3Dmolpromise = $.when($.getScript('http://3dmol.csb.pitt.edu/build/3Dmol.js'))
# var viewer_15270664748821545 = null;
# $3Dmolpromise.done(function() {
# viewer_15270664748821545 = $3Dmol.createViewer($("#3dmolviewer_15270664748821545"),{backgroundColor:"white"});
# 	viewer_15270664748821545.removeAllModels();
# ...

# %% [markdown]
# ### sacharoza5Bn_SPEA_step_938_wB97XD_631gd_INVERSION_try3_step_869_wB97XD_631gd_FREQ.log (19.47%)

# %%
cm1 = open('structures/sacharoza5Bn_SPEA_step_938_wB97XD_631gd_INVERSION_try3_step_869_wB97XD_631gd_FREQ.xyz','r').read()
vcm1 = py3Dmol.view(width=800,height=800)
vcm1.removeAllModels()
vcm1.addModel(cm1,'xyz')
vcm1.setStyle({'stick':{'radius':0.10,'color':'spectrum'}})
vcm1.setBackgroundColor('0x000000')
vcm1.zoomTo()
vcm1.show()
# Out:
# <div id="3dmolviewer_15270664748926144"  style="position: relative; width: 800px; height: 800px">
# <script>
# if(typeof $3Dmolpromise === 'undefined') $3Dmolpromise = $.when($.getScript('http://3dmol.csb.pitt.edu/build/3Dmol.js'))
# var viewer_15270664748926144 = null;
# $3Dmolpromise.done(function() {
# viewer_15270664748926144 = $3Dmol.createViewer($("#3dmolviewer_15270664748926144"),{backgroundColor:"white"});
# 	viewer_15270664748926144.removeAllModels();
# ...

# %% [markdown]
# ### sacharoza5Bn_SPEA_step_938_wB97XD_631gd_INVERSION_try3_step_1159_wB97XD_631gd_FREQ.log (6.07%)

# %%
cm1 = open('structures/sacharoza5Bn_SPEA_step_938_wB97XD_631gd_INVERSION_try3_step_1159_wB97XD_631gd_FREQ.xyz','r').read()
vcm1 = py3Dmol.view(width=800,height=800)
vcm1.removeAllModels()
vcm1.addModel(cm1,'xyz')
vcm1.setStyle({'stick':{'radius':0.10,'color':'spectrum'}})
vcm1.setBackgroundColor('0x000000')
vcm1.zoomTo()
vcm1.show()
# Out:
# <div id="3dmolviewer_15270664748926144"  style="position: relative; width: 800px; height: 800px">
# <script>
# if(typeof $3Dmolpromise === 'undefined') $3Dmolpromise = $.when($.getScript('http://3dmol.csb.pitt.edu/build/3Dmol.js'))
# var viewer_15270664748926144 = null;
# $3Dmolpromise.done(function() {
# viewer_15270664748926144 = $3Dmol.createViewer($("#3dmolviewer_15270664748926144"),{backgroundColor:"white"});
# 	viewer_15270664748926144.removeAllModels();
# ...
