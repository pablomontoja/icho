# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
}
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %%
import glob
import py3Dmol

from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem import Draw
from rdkit.Chem import rdMolAlign
from rdkit.Chem.Draw import IPythonConsole
from rdkit import rdBase
print(rdBase.rdkitVersion)
import os,time
print( time.asctime())
# Out:
# 2016.09.4
# Wed Nov  8 07:48:26 2017

# %% [markdown]
# # Kryptand Kowalskiego + R-PEA

# %% [markdown]
# <table>
#     <tr>
#         <td><b>Nazwa pliku</b></td>
#         <td><b>Energia</b></td>
#         <td><b>Populacja</b></td>
#         <td><b>deltaE (kJ/mol)</b></td>
#     </tr>
#     <tr>
#         <td>cryptand_kowalski_RPEA_v4_27_wB97XD_631gd_V2_try4.log</td>
#         <td>-4516.85472551</td>
#         <td>84.73%</td>
#         <td>0.0</td>
#     </tr>
#     <tr>
#         <td>cryptand_kowalski_RPEA_v4_27_wB97XD_631gd.log</td>
#         <td>-4516.8530733</td>
#         <td>14.726%</td>
#         <td>4.3</td>
#     </tr>
# </table>

# %% [markdown]
# ### cryptand_kowalski_RPEA_v4_27_wB97XD_631gd_V2_try4.log (84.73%) NAJTRWALSZY

# %%
cm1 = open('structures/cryptand_kowalski_RPEA_v4_27_wB97XD_631gd_V2_try4.xyz','r').read()
vcm1 = py3Dmol.view(width=800,height=800)
vcm1.removeAllModels()
vcm1.addModel(cm1,'xyz')
vcm1.setStyle({'stick':{'radius':0.10,'color':'spectrum'}})
vcm1.setBackgroundColor('0x000000')
vcm1.zoomTo()
vcm1.show()
# Out:
# <div id="3dmolviewer_15101237067383492"  style="position: relative; width: 800px; height: 800px">
# <script>
# if(typeof $3Dmolpromise === 'undefined') $3Dmolpromise = $.when($.getScript('http://3dmol.csb.pitt.edu/build/3Dmol.js'))
# var viewer_15101237067383492 = null;
# $3Dmolpromise.done(function() {
# viewer_15101237067383492 = $3Dmol.createViewer($("#3dmolviewer_15101237067383492"),{backgroundColor:"white"});
# 	viewer_15101237067383492.removeAllModels();
# 	viewer_15101237067383492.addModel("210\ncryptand_kowalski_RPEA_v4_27_wB97XD_631gd_V2_try4.gjf\n C                  0.10976900   -1.95392400   -1.81235500\n C                 -0.86278900   -2.94166100   -1.18029000\n C                 -0.63793900   -3.13983800    0.33308500\n C                 -0.03201900   -1.93652000    1.09134000\n C                  0.77774200   -0.96629400    0.21343100\n O                  0.12207100   -0.77998200   -1.00937600\n O                  2.04976600   -1.50901900    0.06502400\n C                  3.10519900   -0.71469700   -0.39689300\n O                  2.78630300   -0.11160400   -1.62890400\n C                  4.28298300   -1.65696600   -0.70133800\n C                  5.03738700   -0.89884200   -1.80948800\n C                  3.88921100   -0.17178600   -2.53050800\n C                  3.53339500    0.33140100    0.63718800\n O                  2.54414800    1.32279900    0.78588500\n C                  3.46190000   -0.87857300   -3.80956400\n C                 -0.28011800   -1.50625200   -3.20105100\n C                  2.91267400    2.31588000    1.72786800\n C                  2.17608100    3.62014600    1.46376000\n O                 -1.52455400   -0.81936700   -3.12519700\n C                 -1.88389100   -0.21344700   -4.34354700\n C                 -3.18492000    0.56298300   -4.21951700\n N                  0.79570700    3.62928700    1.93411900\n O                  2.43578400   -0.19803300   -4.48977600\n C                  2.81672200    0.97933300   -5.17340400\n C                  1.96728400    2.15588500   -4.71515000\n N                  2.34366100    2.71551800   -3.42019900\n N                 -0.85301800    2.82707000   -1.34666300\n C                 -0.53843800    3.72121500   -0.22132100\n C                  0.37161800    2.29336600   -1.98058500\n C                 -1.76564200    3.50655400   -2.28354200\n C                 -0.13040200    2.94273000    1.04508900\n C                 -2.16019200    2.71409800   -3.53697200\n C                  1.18961100    3.32503100   -2.76755000\n N                 -3.21410300    1.71421100   -3.29992100\n O                  3.77968500   -2.85450400   -1.24652500\n C                  4.59818600   -4.40573100    0.47189900\n C                  3.52786700   -4.10103900    1.31283500\n C                  3.54336600   -4.51465600    2.64140200\n C                  4.62089800   -5.24039700    3.14200600\n C                  5.69021100   -5.55093300    2.30421500\n C                  5.67896800   -5.12985900    0.97716400\n C                  4.58400900   -3.98732100   -0.98492500\n O                  5.96721300    0.07060900   -1.37502000\n C                  7.07098800   -0.57020700    0.70918200\n C                  6.96401500    0.57249600    1.50477200\n C                  6.74365700    0.46590100    2.87329200\n C                  6.63176600   -0.79185900    3.46440100\n C                  6.76765600   -1.93784100    2.68652400\n C                  6.99891100   -1.82195100    1.31845200\n C                  7.17137900   -0.42753000   -0.79261800\n O                  0.72863600   -2.43497400    2.17021400\n C                  0.05115300   -0.92465400    3.96843600\n C                 -0.73835300    0.14762500    3.54524600\n C                 -1.82247700    0.57852700    4.30283600\n C                 -2.10124900   -0.03234200    5.52200900\n C                 -1.29961400   -1.07887800    5.97387800\n C                 -0.24024800   -1.53152700    5.19187600\n C                  1.17053700   -1.44806100    3.10160200\n O                 -1.94045900   -3.41715200    0.82995200\n C                 -3.40849400   -3.62926000    2.67646600\n C                 -3.58236600   -2.97643000    3.89402500\n C                 -4.86031200   -2.70832000    4.38044300\n C                 -5.97891200   -3.07595200    3.63971700\n C                 -5.81349600   -3.72009500    2.41280700\n C                 -4.53642800   -4.00095400    1.93911600\n C   ...

# %% [markdown]
# # Kryptand Kowalskiego + S-PEA

# %% [markdown]
# <table>
#     <tr>
#         <td><b>Nazwa pliku</b></td>
#         <td><b>Energia</b></td>
#         <td><b>Populacja</b></td>
#         <td><b>deltaE (kJ/mol)</b></td>
#     </tr>
#     <tr>
#         <td>cryptand_kowalski_SPEA_v4_27_wB97XD_631gd_INVERSION_V2.log</td>
#         <td>-4516.85057748</td>
#         <td>95.45%</td>
#         <td>0.0</td>
#     </tr>
#     <tr>
#         <td>cryptand_kowalski_SPEA_v4_27_wB97XD_631gd_INVERSION.log</td>
#         <td>-4516.84770289</td>
#         <td>4.54%</td>
#         <td>7.55</td>
#     </tr>
# </table>

# %% [markdown]
# ### cryptand_kowalski_SPEA_v4_27_wB97XD_631gd_INVERSION_V2.log (95.45%) NAJTRWALSZY

# %%
cm1 = open('structures/cryptand_kowalski_SPEA_v4_27_wB97XD_631gd_INVERSION_V2.xyz','r').read()
vcm1 = py3Dmol.view(width=800,height=800)
vcm1.removeAllModels()
vcm1.addModel(cm1,'xyz')
vcm1.setStyle({'stick':{'radius':0.10,'color':'spectrum'}})
vcm1.setBackgroundColor('0x000000')
vcm1.zoomTo()
vcm1.show()
# Out:
# <div id="3dmolviewer_15101237067527728"  style="position: relative; width: 800px; height: 800px">
# <script>
# if(typeof $3Dmolpromise === 'undefined') $3Dmolpromise = $.when($.getScript('http://3dmol.csb.pitt.edu/build/3Dmol.js'))
# var viewer_15101237067527728 = null;
# $3Dmolpromise.done(function() {
# viewer_15101237067527728 = $3Dmol.createViewer($("#3dmolviewer_15101237067527728"),{backgroundColor:"white"});
# 	viewer_15101237067527728.removeAllModels();
