# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
}
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %%
import glob
import py3Dmol

from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem import Draw
from rdkit.Chem import rdMolAlign
from rdkit.Chem.Draw import IPythonConsole
from rdkit import rdBase
print(rdBase.rdkitVersion)
import os,time
print( time.asctime())
# Out:
# 2016.09.4
# Tue Jan 16 13:39:18 2018

# %% [markdown]
# # 2ONPy2Me + R-PEA

# %% [markdown]
# <table>
#     <tr>
#         <td><b>Nazwa pliku</b></td>
#         <td><b>Energia</b></td>
#         <td><b>Populacja</b></td>
#         <td><b>deltaE (kJ/mol)</b></td>
#     </tr>
#     <tr>
#         <td>2ONPy2Me_v2_with_RPEA_1_wB97XD_631gd.log</td>
#         <td>-3783.4204512</td>
#         <td>84.43%</td>
#         <td>0.0</td>
#     </tr>
#     <tr>
#         <td>2ONPy2Me_v2_with_RPEA_1_wB97XD_631gd_V2.log</td>
#         <td>-3783.4187074</td>
#         <td>13.32%</td>
#         <td>4.58</td>
#     </tr>
#     <tr>
#         <td>2ONPy2Me_v2_with_RPEA_1_wB97XD_631gd_INVERSION.log</td>
#         <td>-3783.41653906</td>
#         <td>1.34%</td>
#         <td>10.27</td>
#     </tr>
# </table>

# %% [markdown]
# ### 2ONPy2Me_v2_with_RPEA_1_wB97XD_631gd.log (84.43%) NAJTRWALSZY

# %%
cm1 = open('structures/2ONPy2Me_v2_with_RPEA_1_wB97XD_631gd.xyz','r').read()
vcm1 = py3Dmol.view(width=800,height=800)
vcm1.removeAllModels()
vcm1.addModel(cm1,'xyz')
vcm1.setStyle({'stick':{'radius':0.10,'color':'spectrum'}})
vcm1.setBackgroundColor('0x000000')
vcm1.zoomTo()
vcm1.show()
# Out:
# <div id="3dmolviewer_15161063585437007"  style="position: relative; width: 800px; height: 800px">
# <script>
# if(typeof $3Dmolpromise === 'undefined') $3Dmolpromise = $.when($.getScript('http://3dmol.csb.pitt.edu/build/3Dmol.js'))
# var viewer_15161063585437007 = null;
# $3Dmolpromise.done(function() {
# viewer_15161063585437007 = $3Dmol.createViewer($("#3dmolviewer_15161063585437007"),{backgroundColor:"white"});
# 	viewer_15161063585437007.removeAllModels();
# ...

# %% [markdown]
# # 2ONPy2Me + S-PEA

# %% [markdown]
# <table>
#     <tr>
#         <td><b>Nazwa pliku</b></td>
#         <td><b>Energia</b></td>
#         <td><b>Populacja</b></td>
#         <td><b>deltaE (kJ/mol)</b></td>
#     </tr>
#     <tr>
#         <td>2ONPy2Me_v2_with_SPEA_1_wB97XD_631gd_step_479.log</td>
#         <td>-3783.42580023</td>
#         <td>93.30%</td>
#         <td>0.0</td>
#     </tr>
#     <tr>
#         <td>2ONPy2Me_v2_with_SPEA_1_wB97XD_631gd_step_143.log</td>
#         <td>-3783.42250446</td>
#         <td>2.84%</td>
#         <td>8.65</td>
#     </tr>
#     <tr>
#         <td>2ONPy2Me_v2_with_SPEA_1_wB97XD_631gd.log</td>
#         <td>-3783.42212454</td>
#         <td>1.90%</td>
#         <td>9.65</td>
#     </tr>
#     <tr>
#         <td>2ONPy2Me_v2_with_SPEA_2_wB97XD_631gd_INVERSION_OPT.log</td>
#         <td>-3783.42169356</td>
#         <td>1.20%</td>
#         <td>10.78</td>
#     </tr>
# </table>

# %% [markdown]
# ### 2ONPy2Me_v2_with_SPEA_1_wB97XD_631gd_step_479.log (93.30%) NAJTRWALSZY

# %%
cm1 = open('structures/2ONPy2Me_v2_with_SPEA_1_wB97XD_631gd_step_479.xyz','r').read()
vcm1 = py3Dmol.view(width=800,height=800)
vcm1.removeAllModels()
vcm1.addModel(cm1,'xyz')
vcm1.setStyle({'stick':{'radius':0.10,'color':'spectrum'}})
vcm1.setBackgroundColor('0x000000')
vcm1.zoomTo()
vcm1.show()
# Out:
# <div id="3dmolviewer_1516106358554794"  style="position: relative; width: 800px; height: 800px">
# <script>
# if(typeof $3Dmolpromise === 'undefined') $3Dmolpromise = $.when($.getScript('http://3dmol.csb.pitt.edu/build/3Dmol.js'))
# var viewer_1516106358554794 = null;
# $3Dmolpromise.done(function() {
# viewer_1516106358554794 = $3Dmol.createViewer($("#3dmolviewer_1516106358554794"),{backgroundColor:"white"});
# 	viewer_1516106358554794.removeAllModels();
# ...
