# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
}
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %%
import glob
import py3Dmol

from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem import Draw
from rdkit.Chem import rdMolAlign
from rdkit.Chem.Draw import IPythonConsole
from rdkit import rdBase
print(rdBase.rdkitVersion)
import os,time
print( time.asctime())
# Out:
# 2016.09.4
# Wed Mar 14 13:17:28 2018

# %% [markdown]
# # 2NBnO6 + R-PEA

# %% [markdown]
# <table>
#     <tr>
#         <td><b>Nazwa pliku</b></td>
#         <td><b>Energia</b></td>
#         <td><b>Populacja</b></td>
#         <td><b>deltaE (kJ/mol)</b></td>
#     </tr>
#     <tr>
#         <td>2NBnO6_with_RPEA_v1_18_wB97XD_631gd_OPT.log</td>
#         <td>-4017.81370322</td>
#         <td>99.92%</td>
#         <td>0.0</td>
#     </tr>
# </table>

# %% [markdown]
# ### 2NBnO6_with_RPEA_v1_18_wB97XD_631gd_OPT.log (99.92%) NAJTRWALSZY

# %%
cm1 = open('structures/2NBnO6_with_RPEA_v1_18_wB97XD_631gd_FREQ.xyz','r').read()
vcm1 = py3Dmol.view(width=800,height=800)
vcm1.removeAllModels()
vcm1.addModel(cm1,'xyz')
vcm1.setStyle({'stick':{'radius':0.10,'color':'spectrum'}})
vcm1.setBackgroundColor('0x000000')
vcm1.zoomTo()
vcm1.show()
# Out:
# <div id="3dmolviewer_15210298489429812"  style="position: relative; width: 800px; height: 800px">
# <script>
# if(typeof $3Dmolpromise === 'undefined') $3Dmolpromise = $.when($.getScript('http://3dmol.csb.pitt.edu/build/3Dmol.js'))
# var viewer_15210298489429812 = null;
# $3Dmolpromise.done(function() {
# viewer_15210298489429812 = $3Dmol.createViewer($("#3dmolviewer_15210298489429812"),{backgroundColor:"white"});
# 	viewer_15210298489429812.removeAllModels();
# ...

# %% [markdown]
# # 2NBnO6 + S-PEA

# %% [markdown]
# <table>
#     <tr>
#         <td><b>Nazwa pliku</b></td>
#         <td><b>Energia</b></td>
#         <td><b>Populacja</b></td>
#         <td><b>deltaE (kJ/mol)</b></td>
#     </tr>
#     <tr>
#         <td>2NBnO6_with_SPEA_v1_18_wB97XD_631gd_OPT_INVERSION_V2.log</td>
#         <td>-4017.81320938</td>
#         <td>98.10%</td>
#         <td>0.0</td>
#     </tr>
#     <tr>
#         <td>2NBnO6_with_SPEA_v2_11_wB97XD_631gd_OPT.log</td>
#         <td>-4017.80892461</td>
#         <td>1.05%</td>
#         <td>11.25</td>
#     </tr>
# </table>

# %% [markdown]
# ### 2NBnO6_with_SPEA_v1_18_wB97XD_631gd_OPT_INVERSION_V2.log (98.10%) NAJTRWALSZY

# %%
cm1 = open('structures/2NBnO6_with_SPEA_v1_18_wB97XD_631gd_OPT_INVERSION_V2_FREQ.xyz','r').read()
vcm1 = py3Dmol.view(width=800,height=800)
vcm1.removeAllModels()
vcm1.addModel(cm1,'xyz')
vcm1.setStyle({'stick':{'radius':0.10,'color':'spectrum'}})
vcm1.setBackgroundColor('0x000000')
vcm1.zoomTo()
vcm1.show()
# Out:
# <div id="3dmolviewer_15210298489636867"  style="position: relative; width: 800px; height: 800px">
# <script>
# if(typeof $3Dmolpromise === 'undefined') $3Dmolpromise = $.when($.getScript('http://3dmol.csb.pitt.edu/build/3Dmol.js'))
# var viewer_15210298489636867 = null;
# $3Dmolpromise.done(function() {
# viewer_15210298489636867 = $3Dmol.createViewer($("#3dmolviewer_15210298489636867"),{backgroundColor:"white"});
# 	viewer_15210298489636867.removeAllModels();
# ...
