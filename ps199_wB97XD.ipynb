# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
}
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %%
import glob
import py3Dmol

from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem import Draw
from rdkit.Chem import rdMolAlign
from rdkit.Chem.Draw import IPythonConsole
from rdkit import rdBase
print(rdBase.rdkitVersion)
import os,time
print( time.asctime())
# Out:
# 2016.09.4
# Thu Jun 14 13:23:32 2018

# %% [markdown]
# # ps199 + R-PEA

# %% [markdown]
# <table>
#     <tr>
#         <td><b>Nazwa pliku</b></td>
#         <td><b>G</b></td>
#         <td><b>Populacja</b></td>
#         <td><b>deltaG (kJ/mol)</b></td>
#     </tr>
#     <tr>
#         <td>ps199_RPEA_v1_11_wB97XD_631gd_step_12_wB97XD_631gd_INVERSION_v2_CP.log</td>
#         <td>-4165.39626148</td>
#         <td>46.92%</td>
#         <td>0.0</td>
#     </tr>
#     <tr>
#         <td>ps199_RPEA_v3_7_wB97XD_631gd_FREQ.log</td>
#         <td>-4165.39612421</td>
#         <td>40.57%</td>
#         <td>0.36</td>
#     </tr>
#     <tr>
#         <td>ps199_RPEA_v1_11_wB97XD_631gd_step_12_wB97XD_631gd_INVERSION_CP.log</td>
#         <td>-4165.39485433</td>
#         <td>10.57%</td>
#         <td>3.69</td>
#     </tr>
# </table>

# %% [markdown]
# ### ps199_RPEA_v1_11_wB97XD_631gd_step_12_wB97XD_631gd_INVERSION_v2_CP.log (46.92%) NAJTRWALSZY

# %%
cm1 = open('structures/ps199_RPEA_v1_11_wB97XD_631gd_step_12_wB97XD_631gd_INVERSION_v2_CP.xyz','r').read()
vcm1 = py3Dmol.view(width=800,height=800)
vcm1.removeAllModels()
vcm1.addModel(cm1,'xyz')
vcm1.setStyle({'stick':{'radius':0.10,'color':'spectrum'}})
vcm1.setBackgroundColor('0x000000')
vcm1.zoomTo()
vcm1.show()
# Out:
# <div id="3dmolviewer_15289754125256126"  style="position: relative; width: 800px; height: 800px">
# <script>
# if(typeof $3Dmolpromise === 'undefined') $3Dmolpromise = $.when($.getScript('http://3dmol.csb.pitt.edu/build/3Dmol.js'))
# var viewer_15289754125256126 = null;
# $3Dmolpromise.done(function() {
# viewer_15289754125256126 = $3Dmol.createViewer($("#3dmolviewer_15289754125256126"),{backgroundColor:"white"});
# 	viewer_15289754125256126.removeAllModels();
# ...

# %% [markdown]
# ### ps199_RPEA_v3_7_wB97XD_631gd_FREQ.log (40.57%)

# %%
cm1 = open('structures/ps199_RPEA_v3_7_wB97XD_631gd.xyz','r').read()
vcm1 = py3Dmol.view(width=800,height=800)
vcm1.removeAllModels()
vcm1.addModel(cm1,'xyz')
vcm1.setStyle({'stick':{'radius':0.10,'color':'spectrum'}})
vcm1.setBackgroundColor('0x000000')
vcm1.zoomTo()
vcm1.show()
# Out:
# <div id="3dmolviewer_15289754125388453"  style="position: relative; width: 800px; height: 800px">
# <script>
# if(typeof $3Dmolpromise === 'undefined') $3Dmolpromise = $.when($.getScript('http://3dmol.csb.pitt.edu/build/3Dmol.js'))
# var viewer_15289754125388453 = null;
# $3Dmolpromise.done(function() {
# viewer_15289754125388453 = $3Dmol.createViewer($("#3dmolviewer_15289754125388453"),{backgroundColor:"white"});
# 	viewer_15289754125388453.removeAllModels();
# ...

# %% [markdown]
# # ps199 + S-PEA

# %% [markdown]
# <table>
#     <tr>
#         <td><b>Nazwa pliku</b></td>
#         <td><b>G</b></td>
#         <td><b>Populacja</b></td>
#         <td><b>deltaG (kJ/mol)</b></td>
#     </tr>
#     <tr>
#         <td>ps199_SPEA_v1_11_wB97XD_631gd_step_12_wB97XD_631gd_FREQ_CP.log</td>
#         <td>-4165.39550591</td>
#         <td>94.27%</td>
#         <td>0.0</td>
#     </tr>
#     <tr>
#         <td>ps199_SPEA_v1_11_wB97XD_631gd_step_371_wB97XD_631gd_FREQ_CP.log</td>
#         <td>-4165.39232089</td>
#         <td>3.23%</td>
#         <td>8.36</td>
#     </tr>
#     <tr>
#         <td>ps199_SPEA_v1_11_wB97XD_631gd_FREQ.log</td>
#         <td>-4165.39157572</td>
#         <td>1.47%</td>
#         <td>10.32</td>
#     </tr>
# </table>

# %% [markdown]
# ### ps199_SPEA_v1_11_wB97XD_631gd.log (58.72%) NAJTRWALSZY

# %%
cm1 = open('structures/ps199_SPEA_v1_11_wB97XD_631gd_step_12_wB97XD_631gd_FREQ_CP.xyz','r').read()
vcm1 = py3Dmol.view(width=800,height=800)
vcm1.removeAllModels()
vcm1.addModel(cm1,'xyz')
vcm1.setStyle({'stick':{'radius':0.10,'color':'spectrum'}})
vcm1.setBackgroundColor('0x000000')
vcm1.zoomTo()
vcm1.show()
# Out:
# <div id="3dmolviewer_1528975412550797"  style="position: relative; width: 800px; height: 800px">
# <script>
# if(typeof $3Dmolpromise === 'undefined') $3Dmolpromise = $.when($.getScript('http://3dmol.csb.pitt.edu/build/3Dmol.js'))
# var viewer_1528975412550797 = null;
# $3Dmolpromise.done(function() {
# viewer_1528975412550797 = $3Dmol.createViewer($("#3dmolviewer_1528975412550797"),{backgroundColor:"white"});
# 	viewer_1528975412550797.removeAllModels();
# ...
