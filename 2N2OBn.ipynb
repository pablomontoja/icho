# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
}
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %%
import glob
import py3Dmol

from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem import Draw
from rdkit.Chem import rdMolAlign
from rdkit.Chem.Draw import IPythonConsole
from rdkit import rdBase
print(rdBase.rdkitVersion)
import os,time
print( time.asctime())
# Out:
# 2016.09.4
# Mon Jul 31 09:11:02 2017

# %% [markdown]
# <table>
#     <tr>
#         <td><b>Nazwa pliku</b></td>
#         <td><b>Energia</b></td>
#         <td><b>Populacja</b></td>
#         <td><b>deltaE (kJ/mol)</b></td>
#     </tr>
#     <tr>
#         <td>2N2OBn_with_RPEA_v2__4_m052x_631gd_INVERSION.log</td>
#         <td>-4172.3953523</td>
#         <td>79.63%</td>
#         <td>0.0</td>
#     </tr>
#     <tr>
#         <td>2N2OBn_v2_3_with_RPEA_m052x_631gd.log</td>
#         <td>-4172.3935285</td>
#         <td>11.54%</td>
#         <td>0.0</td>
#     </tr>
#     <tr>
#         <td>2N2OBn_v2_1_with_RPEA_m052x_631gd.log</td>
#         <td>-4172.39326416</td>
#         <td>8.72%</td>
#         <td>0.694</td>
#     </tr>
# </table>

# %% [markdown]
# # 2N2OBn + R-PEA
# ## 2N2OBn_with_RPEA_v2__4_m052x_631gd_INVERSION.log (79.63%) NAJTRWALSZY

# %%
cm3 = open('structures/2N2OBn_with_RPEA_v2__4_m052x_631gd_INVERSION.xyz','r').read()
vcm1 = py3Dmol.view(width=800,height=800)
vcm1.removeAllModels()
vcm1.addModel(cm3,'xyz')
vcm1.setStyle({'stick':{'radius':0.10,'color':'spectrum'}})
vcm1.setBackgroundColor('0x000000')
vcm1.zoomTo()
vcm1.show()
# Out:
# <div id="3dmolviewer_15014850620684295"  style="position: relative; width: 800px; height: 800px">
# <script>
# if(typeof $3Dmolpromise === 'undefined') $3Dmolpromise = $.when($.getScript('http://3dmol.csb.pitt.edu/build/3Dmol.js'))
# var viewer_15014850620684295 = null;
# $3Dmolpromise.done(function() {
# viewer_15014850620684295 = $3Dmol.createViewer($("#3dmolviewer_15014850620684295"),{backgroundColor:"white"});
# 	viewer_15014850620684295.removeAllModels();
# ...

# %% [markdown]
# ## 2N2OBn_v2_3_with_RPEA_m052x_631gd.log (11.54%)

# %%
cm1 = open('structures/2N2OBn_v2_3_with_RPEA_m052x_631gd.xyz','r').read()
vcm1 = py3Dmol.view(width=800,height=800)
vcm1.removeAllModels()
vcm1.addModel(cm1,'xyz')
vcm1.setStyle({'stick':{'radius':0.10,'color':'spectrum'}})
vcm1.setBackgroundColor('0x000000')
vcm1.zoomTo()
vcm1.show()
# Out:
# <div id="3dmolviewer_15014850620857003"  style="position: relative; width: 800px; height: 800px">
# <script>
# if(typeof $3Dmolpromise === 'undefined') $3Dmolpromise = $.when($.getScript('http://3dmol.csb.pitt.edu/build/3Dmol.js'))
# var viewer_15014850620857003 = null;
# $3Dmolpromise.done(function() {
# viewer_15014850620857003 = $3Dmol.createViewer($("#3dmolviewer_15014850620857003"),{backgroundColor:"white"});
# 	viewer_15014850620857003.removeAllModels();
# ...

# %% [markdown]
# ## 2N2OBn_v2_1_with_RPEA_m052x_631gd.log (8.72%)

# %%
cm2 = open('structures/2N2OBn_v2_1_with_RPEA_m052x_631gd.xyz','r').read()
vcm1 = py3Dmol.view(width=800,height=800)
vcm1.removeAllModels()
vcm1.addModel(cm2,'xyz')
vcm1.setStyle({'stick':{'radius':0.10,'color':'spectrum'}})
vcm1.setBackgroundColor('0x000000')
vcm1.zoomTo()
vcm1.show()
# Out:
# <div id="3dmolviewer_15014850620977252"  style="position: relative; width: 800px; height: 800px">
# <script>
# if(typeof $3Dmolpromise === 'undefined') $3Dmolpromise = $.when($.getScript('http://3dmol.csb.pitt.edu/build/3Dmol.js'))
# var viewer_15014850620977252 = null;
# $3Dmolpromise.done(function() {
# viewer_15014850620977252 = $3Dmol.createViewer($("#3dmolviewer_15014850620977252"),{backgroundColor:"white"});
# 	viewer_15014850620977252.removeAllModels();
# ...

# %% [markdown]
# # 2N2OBn + S-PEA
# ## 2N2OBn_with_SPEA_v2__4_m052x_631gd.log (99.447%) NAJTRWALSZY

# %% [markdown]
# <table>
#     <tr>
#         <td><b>Nazwa pliku</b></td>
#         <td><b>Energia</b></td>
#         <td><b>Populacja</b></td>
#         <td><b>deltaE (kJ/mol)</b></td>
#     </tr>
#     <tr>
#         <td>2N2OBn_with_SPEA_v2__4_m052x_631gd.log</td>
#         <td>-4172.39832364</td>
#         <td>99.447%</td>
#         <td>0.0</td>
#     </tr>
#     <tr>
#         <td>2N2OBn_with_SPEA_v2__19_m052x_631gd.log</td>
#         <td>-4172.39340596 </td>
#         <td>0.544%</td>
#         <td>12.91</td>
#     </tr>
# </table>

# %%
cm3 = open('structures/2N2OBn_with_SPEA_v2__4_m052x_631gd.xyz','r').read()
vcm1 = py3Dmol.view(width=800,height=800)
vcm1.removeAllModels()
vcm1.addModel(cm3,'xyz')
vcm1.setStyle({'stick':{'radius':0.10,'color':'spectrum'}})
vcm1.setBackgroundColor('0x000000')
vcm1.zoomTo()
vcm1.show()
# Out:
# <div id="3dmolviewer_15014850621098938"  style="position: relative; width: 800px; height: 800px">
# <script>
# if(typeof $3Dmolpromise === 'undefined') $3Dmolpromise = $.when($.getScript('http://3dmol.csb.pitt.edu/build/3Dmol.js'))
# var viewer_15014850621098938 = null;
# $3Dmolpromise.done(function() {
# viewer_15014850621098938 = $3Dmol.createViewer($("#3dmolviewer_15014850621098938"),{backgroundColor:"white"});
# 	viewer_15014850621098938.removeAllModels();
# ...
