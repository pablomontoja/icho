# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
}
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %%
import glob
import py3Dmol

from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem import Draw
from rdkit.Chem import rdMolAlign
from rdkit.Chem.Draw import IPythonConsole
from rdkit import rdBase
print(rdBase.rdkitVersion)
import os,time
print( time.asctime())
# Out:
# 2016.09.4
# Mon Aug 21 09:45:03 2017

# %% [markdown]
# # 3NBn + R-PEA

# %% [markdown]
# <table>
#     <tr>
#         <td><b>Nazwa pliku</b></td>
#         <td><b>Energia</b></td>
#         <td><b>Populacja</b></td>
#         <td><b>deltaE (kJ/mol)</b></td>
#     </tr>
#     <tr>
#         <td>3NBn_2_v2_with_RPEA_33_wB97XD_631gd.log</td>
#         <td>-4268.22638334</td>
#         <td>99.51%</td>
#         <td>0.0</td>
#     </tr>
#     <tr>
#         <td>3NBn_2_v2_with_RPEA_22_wB97XD_631gd.log</td>
#         <td>-4268.22127029</td>
#         <td>0.44%</td>
#         <td>13.42</td>
#     </tr>
#     <tr>
#         <td>3NBn_2_v2_with_RPEA_17_wB97XD_631gd.log</td>
#         <td>-4268.2189442</td>
#         <td>0.04%</td>
#         <td>19.53</td>
#     </tr>
# </table>

# %% [markdown]
# ### 3NBn_2_v2_with_RPEA_33_wB97XD_631gd.log (99.51%) NAJTRWALSZY

# %%
cm1 = open('structures/3NBn_2_v2_with_RPEA_33_wB97XD_631gd.xyz','r').read()
vcm1 = py3Dmol.view(width=800,height=800)
vcm1.removeAllModels()
vcm1.addModel(cm1,'xyz')
vcm1.setStyle({'stick':{'radius':0.10,'color':'spectrum'}})
vcm1.setBackgroundColor('0x000000')
vcm1.zoomTo()
vcm1.show()
# Out:
# <div id="3dmolviewer_15033015035780284"  style="position: relative; width: 800px; height: 800px">
# <script>
# if(typeof $3Dmolpromise === 'undefined') $3Dmolpromise = $.when($.getScript('http://3dmol.csb.pitt.edu/build/3Dmol.js'))
# var viewer_15033015035780284 = null;
# $3Dmolpromise.done(function() {
# viewer_15033015035780284 = $3Dmol.createViewer($("#3dmolviewer_15033015035780284"),{backgroundColor:"white"});
# 	viewer_15033015035780284.removeAllModels();
# ...

# %% [markdown]
# # 3NBn + S-PEA

# %% [markdown]
# <table>
#     <tr>
#         <td><b>Nazwa pliku</b></td>
#         <td><b>Energia</b></td>
#         <td><b>Populacja</b></td>
#         <td><b>deltaE (kJ/mol)</b></td>
#     </tr>
#     <tr>
#         <td>3NBn_2_v2_with_SPEA_33_wB97XD_631gd_INVERSION.log</td>
#         <td>-4268.22611664</td>
#         <td>99.998%</td>
#         <td>0.0</td>
#     </tr>
# </table>

# %% [markdown]
# ### 3NBn_2_v2_with_SPEA_33_wB97XD_631gd_INVERSION.log (99.998%) NAJTRWALSZY

# %%
cm1 = open('structures/3NBn_2_v2_with_SPEA_33_wB97XD_631gd_INVERSION.xyz','r').read()
vcm1 = py3Dmol.view(width=800,height=800)
vcm1.removeAllModels()
vcm1.addModel(cm1,'xyz')
vcm1.setStyle({'stick':{'radius':0.10,'color':'spectrum'}})
vcm1.setBackgroundColor('0x000000')
vcm1.zoomTo()
vcm1.show()
# Out:
# <div id="3dmolviewer_15033015036245205"  style="position: relative; width: 800px; height: 800px">
# <script>
# if(typeof $3Dmolpromise === 'undefined') $3Dmolpromise = $.when($.getScript('http://3dmol.csb.pitt.edu/build/3Dmol.js'))
# var viewer_15033015036245205 = null;
# $3Dmolpromise.done(function() {
# viewer_15033015036245205 = $3Dmol.createViewer($("#3dmolviewer_15033015036245205"),{backgroundColor:"white"});
# 	viewer_15033015036245205.removeAllModels();
# ...
