# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
}
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %%
import glob
import py3Dmol

from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem import Draw
from rdkit.Chem import rdMolAlign
from rdkit.Chem.Draw import IPythonConsole
from rdkit import rdBase
print(rdBase.rdkitVersion)
import os,time
print( time.asctime())
# Out:
# 2016.09.4
# Tue Oct 17 12:37:08 2017

# %% [markdown]
# # Kryptand Kowalskiego + R-PEA

# %% [markdown]
# <table>
#     <tr>
#         <td><b>Nazwa pliku</b></td>
#         <td><b>Energia</b></td>
#         <td><b>Populacja</b></td>
#         <td><b>deltaE (kJ/mol)</b></td>
#     </tr>
#     <tr>
#         <td>cryptand_kowalski_RPEA_v4_27_wB97XD_631gd.log</td>
#         <td>-4516.8530733</td>
#         <td>96.47%</td>
#         <td>0.0</td>
#     </tr>
#     <tr>
#         <td>cryptand_kowalski_withRPEA_v3_3_wB97XD_631gd.log</td>
#         <td>-4516.84960987</td>
#         <td>2.46%</td>
#         <td>9.09</td>
#     </tr>
#     <tr>
#         <td>cryptand_kowalski_withRPEA_v3_5_wB97XD_631gd.log</td>
#         <td>-4516.84853007</td>
#         <td>0.78%</td>
#         <td>11.93</td>
#     </tr>
# </table>

# %% [markdown]
# ### cryptand_kowalski_RPEA_v4_27_wB97XD_631gd.log (96.47%) NAJTRWALSZY

# %%
cm1 = open('structures/cryptand_kowalski_RPEA_v4_27_wB97XD_631gd.xyz','r').read()
vcm1 = py3Dmol.view(width=800,height=800)
vcm1.removeAllModels()
vcm1.addModel(cm1,'xyz')
vcm1.setStyle({'stick':{'radius':0.10,'color':'spectrum'}})
vcm1.setBackgroundColor('0x000000')
vcm1.zoomTo()
vcm1.show()
# Out:
# <div id="3dmolviewer_1508236628885773"  style="position: relative; width: 800px; height: 800px">
# <script>
# if(typeof $3Dmolpromise === 'undefined') $3Dmolpromise = $.when($.getScript('http://3dmol.csb.pitt.edu/build/3Dmol.js'))
# var viewer_1508236628885773 = null;
# $3Dmolpromise.done(function() {
# viewer_1508236628885773 = $3Dmol.createViewer($("#3dmolviewer_1508236628885773"),{backgroundColor:"white"});
# 	viewer_1508236628885773.removeAllModels();
# ...

# %% [markdown]
# # Kryptand Kowalskiego + S-PEA

# %% [markdown]
# <table>
#     <tr>
#         <td><b>Nazwa pliku</b></td>
#         <td><b>Energia</b></td>
#         <td><b>Populacja</b></td>
#         <td><b>deltaE (kJ/mol)</b></td>
#     </tr>
#     <tr>
#         <td>cryptand_kowalski_SPEA_v4_27_wB97XD_631gd_INVERSION_V2.log</td>
#         <td>-1664.10693438</td>
#         <td>95.45%</td>
#         <td>0.0</td>
#     </tr>
#     <tr>
#         <td>cryptand_kowalski_SPEA_v4_27_wB97XD_631gd_INVERSION.log</td>
#         <td>-1664.1035282</td>
#         <td>4.54%</td>
#         <td>7.55</td>
#     </tr>
# </table>

# %% [markdown]
# ### cryptand_kowalski_SPEA_v4_27_wB97XD_631gd_INVERSION_V2.log (95.45%) NAJTRWALSZY

# %%
cm1 = open('structures/cryptand_kowalski_SPEA_v4_27_wB97XD_631gd_INVERSION_V2.xyz','r').read()
vcm1 = py3Dmol.view(width=800,height=800)
vcm1.removeAllModels()
vcm1.addModel(cm1,'xyz')
vcm1.setStyle({'stick':{'radius':0.10,'color':'spectrum'}})
vcm1.setBackgroundColor('0x000000')
vcm1.zoomTo()
vcm1.show()
# Out:
# <div id="3dmolviewer_15082366289262872"  style="position: relative; width: 800px; height: 800px">
# <script>
# if(typeof $3Dmolpromise === 'undefined') $3Dmolpromise = $.when($.getScript('http://3dmol.csb.pitt.edu/build/3Dmol.js'))
# var viewer_15082366289262872 = null;
# $3Dmolpromise.done(function() {
# viewer_15082366289262872 = $3Dmol.createViewer($("#3dmolviewer_15082366289262872"),{backgroundColor:"white"});
# 	viewer_15082366289262872.removeAllModels();
# ...
